# %%
import sys
sys.path.append('..')

# %%
import matplotlib.pyplot as plt
import pandas as pd

from config.project_config import get_data_path

# Analyses
from src.analyses.schedule_jobs_dataframe import jobs_metrics_from_operations_df, mean_start_deviation_per_shift_df


# Plots
from src.analyses.fig_experiment import make_combined_figure_startdeviation_tardiness_earliness

# %%
# sub_directory = "2025_09_01"
sub_directory = None  # Use root data directory
max_utilization  = 0.75

experiments_file_path = get_data_path(
    sub_directory,
    f"experiments_{max_utilization:.2f}".replace(".", "_")
)

schedules_file_path = get_data_path(
        sub_directory,
        f"schedules_{max_utilization:.2f}".replace(".", "_")
)

# %%
df_experiments = pd.read_csv(f"{experiments_file_path}.csv")
df_experiments
# Out:
#     Experiment_ID  Abs Lateness Ratio  Inner Tardiness Ratio  \
# 0               1                0.00                    0.0
# 1               2                0.00                    0.0
# 2               3                0.00                    0.0
# 3               4                0.00                    0.0
# 4               5                0.00                    0.0
# 5               6                0.00                    0.0
# 6               7                0.00                    0.0
# 7               8                0.00                    0.0
# 8               9                0.00                    0.0
# 9              10                0.00                    0.0
# 10             11                0.00                    0.0
# 11             12                0.00                    0.0
# 12             13                0.00                    0.0
# 13             14                0.00                    0.0
# 14             15                0.00                    0.0
# 15             16                0.00                    0.0
# 16             17                0.00                    0.0
# 17             18                0.00                    0.0
# 18             19                0.00                    0.0
# 19             20                0.00                    0.0
# 20             21                0.00                    0.0
# 21             22                0.00                    0.0
# 22             23                0.00                    0.0
# 23             24                0.00                    0.0
# 24             25                0.00                    0.0
# 25             26                0.00                    0.0
# 26             27                0.00                    0.0
# 27             28                0.00                    0.0
# 28             29                0.00                    0.0
# 29             30                0.00                    0.0
# 30             31                0.25                    1.0
# 31             32                0.25                    1.0
# 32             34                0.00                    0.0
# 33             37                0.00                    0.0
# 34             38                0.00                    0.0
#
#     Max Bottleneck Utilization  Sim Sigma  Shift Length  w_t  w_e  w_dev  \
# 0                         0.75        0.1          1440    0    0      1
# 1                         0.75        0.1          1440    0    0      1
# 2                         0.75        0.1          1440    0    0      1
# 3                         0.75        0.1          1440    0    0      1
# 4                         0.75        0.1          1440    0    0      1
# 5                         0.75        0.1          1440    0    0      1
# 6                         0.75        0.1          1440    0    0      1
# 7                         0.75        0.1          1440    0    0      1
# 8                         0.75        0.1          1440    0    0      1
# 9                         0.75        0.1          1440    0    0      1
# 10                        0.75        0.1          1440    0    0      1
# 11                        0.75        0.1          1440    0    0      1
# 12                        0.75        0.1          1440    0    0      1
# 13                        0.75        0.1          1440    0    0      1
# 14                        0.75        0.1          1440    0    0      1
# 15                        0.75        0.1          1440    0    0      1
# 16                        0.75        0.1          1440    0    0      1
# 17                        0.75        0.1          1440    0    0      1
# 18                        0.75        0.1          1440    0    0      1
# 19                        0.75        0.1          1440    0    0      1
# 20                        0.75        0.1          1440    0    0      1
# 21                        0.75        0.1          1440    0    0      1
# 22                        0.75        0.1          1440    0    0      1
# 23                        0.75        0.1          1440    0    0      1
# 24                        0.75        0.1          1440    0    0      1
# 25                        0.75        0.1          1440    0    0      1
# 26                        0.75        0.1          1440    0    0      1
# 27                        0.75        0.1          1440    0    0      1
# 28                        0.75        0.1          1440    0    0      1
# 29                        0.75        0.1          1440    0    0      1
# 30                        0.75        0.1          1440    1    0      3
# 31                        0.75        0.1          1440    1    0      3
# 32                        0.75        0.1          1440    0    0      1
# 33                        0.75        0.1          1440    0    0      1
# 34                        0.75        0.1          1440    0    0      1
#
#    Experiment_Type
# 0         GT_SLACK
# 1              BnB
# 2              BnB
# 3              BnB
# 4              BnB
# 5              BnB
# 6              BnB
# 7              BnB
# 8              BnB
# 9              BnB
# 10             BnB
# 11        GT_SLACK
# 12             BnB
# 13             BnB
# 14             BnB
# 15             BnB
# 16             BnB
# 17             BnB
# 18             BnB
# 19             BnB
# 20             BnB
# 21             BnB
# 22             BnB
# 23             BnB
# 24             BnB
# 25             BnB
# 26             BnB
# 27             BnB
# 28             BnB
# 29        GT_SLACK
# 30              CP
# 31              CP
# 32        BnB_Test
# 33      BNB_SINGLE
# 34      BNB_SINGLE

# %%
df_schedules = pd.read_csv(f"{schedules_file_path}.csv")
df_schedules
# Out:
#                  Job Routing_ID  Experiment_ID  Arrival  Ready Time  Due Date  \
# 0      01-07500-0000      01-07              1        0        1440      3405
# 1      01-07500-0000      01-07              2        0        1440      3405
# 2      01-07500-0000      01-07              3        0        1440      3405
# 3      01-07500-0000      01-07              4        0        1440      3405
# 4      01-07500-0000      01-07              5        0        1440      3405
# ...              ...        ...            ...      ...         ...       ...
# 31523  01-07500-0365      01-04              3    31643       31680     34575
# 31524  01-07500-0365      01-04              4    31643       31680     34575
# 31525  01-07500-0365      01-04              5    31643       31680     34575
# 31526  01-07500-0365      01-04              6    31643       31680     34575
# 31527  01-07500-0365      01-04              7    31643       31680     34575
#
#        Shift  Operation Machine  Original Duration  Start    End
# 0          1          0     M02                 31   1524   1555
# 1          1          0     M02                 31   1524   1555
# 2          1          0     M02                 31   1524   1555
# 3          1          0     M02                 31   1524   1555
# 4          1          0     M02                 31   1524   1555
# ...      ...        ...     ...                ...    ...    ...
# 31523     22          9     M06                 53  33751  33804
# 31524     22          9     M06                 53  33751  33804
# 31525     22          9     M06                 53  33751  33804
# 31526     22          9     M06                 53  33751  33804
# 31527     22          9     M06                 53  33751  33804
#
# [31528 rows x 12 columns]

# %% [markdown]
# ## Evaluation Dataframes

# %% [markdown]
# ### Tardiness/Earliness (Metrics)

# %%
df_metrics = jobs_metrics_from_operations_df(df_schedules)
df_metrics
# Out:
#                 Job Routing_ID  Experiment_ID  Shift  Arrival  Due Date  \
# 0     01-07500-0000      01-07              1      1        0      3405
# 1     01-07500-0001      01-06              1      1       60      2433
# 2     01-07500-0002      01-01              1      1      142      2766
# 3     01-07500-0003      01-05              1      1      197      2640
# 4     01-07500-0004      01-04              1      1      249      3581
# ...             ...        ...            ...    ...      ...       ...
# 2557  01-07500-0361      01-06              7     22    31468     32664
# 2558  01-07500-0362      01-08              7     22    31521     33040
# 2559  01-07500-0363      01-01              7     22    31593     32538
# 2560  01-07500-0364      01-00              7     22    31630     33419
# 2561  01-07500-0365      01-04              7     22    31643     34575
#
#       Completion  Tardiness  Earliness  Lateness
# 0           3038          0        367      -367
# 1           2298          0        135      -135
# 2           2429          0        337      -337
# 3           2713         73          0        73
# 4           3205          0        376      -376
# ...          ...        ...        ...       ...
# 2557       32421          0        243      -243
# 2558       32611          0        429      -429
# 2559       32247          0        291      -291
# 2560       33314          0        105      -105
# 2561       33804          0        771      -771
#
# [2562 rows x 10 columns]

# %% [markdown]
# ### Start Deviation

# %%
df_dev = mean_start_deviation_per_shift_df(df_schedules)
df_dev.head(12)
# Out:
#      Experiment_ID  Shift   Deviation  Pairs
# 0                1      2   32.210526     19
# 1                1      3  112.666667     24
# 2                1      4  115.488095     84
# 3                1      5   51.592308    130
# 4                1      6   39.144737     76
# ..             ...    ...         ...    ...
# 142              7     18    7.242424     33
# 143              7     19   71.384615     26
# 144              7     20   25.000000      2
# 145              7     21   62.625000      8
# 146              7     22   16.333333      3
#
# [147 rows x 4 columns]

# %% [markdown]
# ## Examples

# %%
df_experiments_filtered = df_experiments[
    (df_experiments["Abs Lateness Ratio"] == 0.5) &
    (df_experiments["Inner Tardiness Ratio"] == 0.5)
]

df_experiments_filtered
# Out:
# Empty DataFrame
# Columns: [Experiment_ID, Abs Lateness Ratio, Inner Tardiness Ratio, Max Bottleneck Utilization, Sim Sigma, Shift Length, w_t, w_e, w_dev, Experiment_Type]
# Index: []

# %%
experiment_id  = 36

# %% [markdown]
# ### Tardiness/Earliness (Metrics)

# %%
from src.analyses.fig_tardiness_earliness import make_fig_tardiness_earliness_only

fig = make_fig_tardiness_earliness_only(df_metrics, experiment_id=experiment_id, y_step=120, show_earliness=True)
plt.show()

# %% [markdown]
# ### Start Deviation

# %%
from src.analyses.fig_startdeviation import make_fig_startdeviation_only

fig = make_fig_startdeviation_only(df_dev, experiment_id=experiment_id, y_step=120)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.analyses.fig_startdeviation import make_fig_startdeviation_only
#       3 fig = make_fig_startdeviation_only(df_dev, experiment_id=experiment_id, y_step=120)
#       4 plt.show()
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# ### Vergleich

# %%
# Check if experiment_id exists in df_dev
if experiment_id in df_dev["Experiment_ID"].values:
    exp_id_to_plot = experiment_id
else:
    print(f"Experiment_ID={experiment_id} not found in df_dev. Using a valid Experiment_ID instead.")
    exp_id_to_plot = df_dev["Experiment_ID"].unique()[0]

fig = make_combined_figure_startdeviation_tardiness_earliness(
    df_dev=df_dev,
    df_metrics=df_metrics,
    experiment_id=exp_id_to_plot,
    y_step=60,
    y_max=720,
    title=f"Experiment {exp_id_to_plot}"
          + f"\nØ Start deviation & Lateness metrics (Tardiness/Earliness)"
)
plt.show()
# Out:
# Experiment_ID=37 not found in df_dev. Using a valid Experiment_ID instead.

# %%
def get_experiment_string(df, experiment_id):
    row = df[df["Experiment_ID"] == experiment_id].iloc[0]
    return (
        f"Experiment {experiment_id}\n"
        f"lateness/deviation = {row['Abs Lateness Ratio']:.2f}, "
        f"tardiness/earliness = {row['Inner Tardiness Ratio']:.2f}, "
        f"bottleneck utilization = {row['Max Bottleneck Utilization']:.2f} "
        f"(sigma = {row['Sim Sigma']:.2f})"
    )

# Beispiel
print(get_experiment_string(df_experiments, 1))
# Out:
# Experiment 7
# lateness/deviation = 0.00, tardiness/earliness = 0.00, bottleneck utilization = 0.75 (sigma = 0.10)

# %%
# experiment_id  = 22
fig = make_combined_figure_startdeviation_tardiness_earliness(
    df_dev=df_dev,
    df_metrics=df_metrics,
    experiment_id=experiment_id,
    y_step=60,
    y_max = 720,
    title=f"{get_experiment_string(df_experiments, experiment_id)}"
)
plt.show()

# %%
df_experiments_filtered = df_experiments[
    (df_experiments["Abs Lateness Ratio"].isin([0.25, 0.5, 0.75, 1])) &
    (df_experiments["Inner Tardiness Ratio"] == 0.75) &
    (df_experiments["Sim Sigma"] == 0.1)
]

experiment_ids = df_experiments_filtered["Experiment_ID"].tolist()


for experiment_id in experiment_ids:
    make_combined_figure_startdeviation_tardiness_earliness(
        df_dev=df_dev,
        df_metrics=df_metrics,
        experiment_id=experiment_id,
        y_step=60,
        y_max = 720,
        title=f"{get_experiment_string(df_experiments, experiment_id)}"
    )
    plt.show()
